# %%
import pandas as pd
movies_df = pd.read_excel('https://query.data.world/s/ynsc7amoi6qiyfm2ekb5cyz6qwepi6')

# %%
movies_df.to_csv("Data_sets/movies_df.csv",index=False)
movies_df.head()
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %% [markdown]
# # Netflix Data

# %%
#Read in netflix data
netflix_df= pd.read_csv("Data_sets/netflix_titles.csv")
#re-add 'director' column
netflix_df= netflix_df.dropna(subset= ['cast'])
netflix_df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country date_added  release_year  \
# ...

# %%
netflix_df['cast'] = netflix_df['cast'].apply(lambda x: x.split(','))

netflix_df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  [Alan Marriott,  Andrew Toth,  Brian Dobson,  ...
# 1                                 [Jandino Asporaat]
# 2  [Peter Cullen,  Sumalee Montano,  Frank Welker...
# 3  [Will Friedle,  Darren Criss,  Constance Zimme...
# 4  [Nesta Cooper,  Kate Walsh,  John Michael Higg...
#
#                                     country date_added  release_year  \
# ...

# %%
netflix_cast= netflix_df.explode('cast')
netflix_cast= netflix_cast[["title","duration","rating","listed_in","release_year","type","director","cast",
                           "country", "date_added"]]
netflix_cast= netflix_cast.rename(columns={"rating":"mpaa_rating","type":"media_type","cast":"netflix_cast"})
netflix_cast.head()
# Out:
#                                      title duration mpaa_rating  \
# 0  Norm of the North: King Sized Adventure   90 min       TV-PG
# 0  Norm of the North: King Sized Adventure   90 min       TV-PG
# 0  Norm of the North: King Sized Adventure   90 min       TV-PG
# 0  Norm of the North: King Sized Adventure   90 min       TV-PG
# 0  Norm of the North: King Sized Adventure   90 min       TV-PG
#
#                             listed_in  release_year media_type  \
# 0  Children & Family Movies, Comedies          2019      Movie
# 0  Children & Family Movies, Comedies          2019      Movie
# 0  Children & Family Movies, Comedies          2019      Movie
# 0  Children & Family Movies, Comedies          2019      Movie
# 0  Children & Family Movies, Comedies          2019      Movie
#
#                    director       netflix_cast  \
# 0  Richard Finn, Tim Maltby      Alan Marriott
# 0  Richard Finn, Tim Maltby        Andrew Toth
# 0  Richard Finn, Tim Maltby       Brian Dobson
# ...

# %%
#Transform data

#Removed unnecessary columns
clean_netflix_df= netflix_df[["title", "duration", "rating", "listed_in", "release_year", "type"]]

#Rename columns
clean_netflix_df= clean_netflix.rename(columns= {"rating":"mpaa_rating", "type":"media_type"})

clean_netflix_df.head()
# Out:
#                                      title  duration mpaa_rating  \
# 0  Norm of the North: King Sized Adventure    90 min       TV-PG
# 1               Jandino: Whatever it Takes    94 min       TV-MA
# 2                       Transformers Prime  1 Season    TV-Y7-FV
# 3         Transformers: Robots in Disguise  1 Season       TV-Y7
# 4                             #realityhigh    99 min       TV-14
#
#                             listed_in  release_year media_type
# 0  Children & Family Movies, Comedies          2019      Movie
# 1                     Stand-Up Comedy          2016      Movie
# 2                            Kids' TV          2013    TV Show
# 3                            Kids' TV          2016    TV Show
# 4                            Comedies          2017      Movie

# %% [markdown]
# # Movie Data

# %%
#Transform data

#Removed unnecessary columns
reduced_movies_df= movies_df[["Title", "Runtime", "MPAA Rating", "Genre", "Release Date",
                              "Rating", "Rating Count", "Budget", "Gross"]]
reduced_movies_df= reduced_movies_df.rename(columns={"Title":"title", "Runtime":"duration", "MPAA Rating":"mpaa_rating",
                                "Genre":"genre", "Release Date":"release_date", "Rating":"user_rating",
                                "Rating Count":"rating_count", "Budget":"budget", "Gross":"gross"})

#reduced_movies_df["Gross"]= round(reduced_movies_df["Gross"]/1000000, 2)
reduced_movies_df.head()
# Out:
#                         title  duration mpaa_rating    genre release_date  \
# 0          Look Who's Talking      93.0       PG-13  Romance   1989-10-12
# 1          Driving Miss Daisy      99.0          PG   Comedy   1989-12-13
# 2              Turner & Hooch     100.0          PG    Crime   1989-07-28
# 3  Born on the Fourth of July     145.0           R      War   1989-12-20
# 4             Field of Dreams     107.0          PG    Drama   1989-04-21
#
#    user_rating  rating_count      budget        gross
# 0          5.9       73638.0   7500000.0  296000000.0
# 1          7.4       91075.0   7500000.0  145793296.0
# 2          7.2       91415.0  13000000.0   71079915.0
# 3          7.2       91415.0  14000000.0  161001698.0
# 4          7.5      101702.0  15000000.0   84431625.0

# %% [markdown]
# ## Transformed DFs

# %%
clean_netflix_df.to_csv("Data_sets/clean_netflix_df.csv",index=False)
netflix_cast.to_csv("Data_sets/clean_netflix_cast_df.csv",index=False)
reduced_movies_df.to_csv("Data_sets/clean_movies_df.csv", index=False)

# %%
clean_netflix_df.head()
# Out:
#                                      title  duration mpaa_rating  \
# 0  Norm of the North: King Sized Adventure    90 min       TV-PG
# 1               Jandino: Whatever it Takes    94 min       TV-MA
# 2                       Transformers Prime  1 Season    TV-Y7-FV
# 3         Transformers: Robots in Disguise  1 Season       TV-Y7
# 4                             #realityhigh    99 min       TV-14
#
#                             listed_in  release_year media_type
# 0  Children & Family Movies, Comedies          2019      Movie
# 1                     Stand-Up Comedy          2016      Movie
# 2                            Kids' TV          2013    TV Show
# 3                            Kids' TV          2016    TV Show
# 4                            Comedies          2017      Movie

# %%
netflix_cast.head()
# Out:
#                                      title duration mpaa_rating  \
# 0  Norm of the North: King Sized Adventure   90 min       TV-PG
# 0  Norm of the North: King Sized Adventure   90 min       TV-PG
# 0  Norm of the North: King Sized Adventure   90 min       TV-PG
# 0  Norm of the North: King Sized Adventure   90 min       TV-PG
# 0  Norm of the North: King Sized Adventure   90 min       TV-PG
#
#                             listed_in  release_year media_type  \
# 0  Children & Family Movies, Comedies          2019      Movie
# 0  Children & Family Movies, Comedies          2019      Movie
# 0  Children & Family Movies, Comedies          2019      Movie
# 0  Children & Family Movies, Comedies          2019      Movie
# 0  Children & Family Movies, Comedies          2019      Movie
#
#                    director       netflix_cast  \
# 0  Richard Finn, Tim Maltby      Alan Marriott
# 0  Richard Finn, Tim Maltby        Andrew Toth
# 0  Richard Finn, Tim Maltby       Brian Dobson
# ...

# %%
reduced_movies_df.head()
# Out:
#                         title  duration mpaa_rating    genre release_date  \
# 0          Look Who's Talking      93.0       PG-13  Romance   1989-10-12
# 1          Driving Miss Daisy      99.0          PG   Comedy   1989-12-13
# 2              Turner & Hooch     100.0          PG    Crime   1989-07-28
# 3  Born on the Fourth of July     145.0           R      War   1989-12-20
# 4             Field of Dreams     107.0          PG    Drama   1989-04-21
#
#    user_rating  rating_count      budget        gross
# 0          5.9       73638.0   7500000.0  296000000.0
# 1          7.4       91075.0   7500000.0  145793296.0
# 2          7.2       91415.0  13000000.0   71079915.0
# 3          7.2       91415.0  14000000.0  161001698.0
# 4          7.5      101702.0  15000000.0   84431625.0

# %%
#Appended dfs
app_net= clean_netflix_df.append(netflix_cast, ignore_index=True)
app_net.head()
# Out:
#                                      title  duration mpaa_rating  \
# 0  Norm of the North: King Sized Adventure    90 min       TV-PG
# 1               Jandino: Whatever it Takes    94 min       TV-MA
# 2                       Transformers Prime  1 Season    TV-Y7-FV
# 3         Transformers: Robots in Disguise  1 Season       TV-Y7
# 4                             #realityhigh    99 min       TV-14
#
#                             listed_in  release_year media_type director  \
# 0  Children & Family Movies, Comedies          2019      Movie      NaN
# 1                     Stand-Up Comedy          2016      Movie      NaN
# 2                            Kids' TV          2013    TV Show      NaN
# 3                            Kids' TV          2016    TV Show      NaN
# 4                            Comedies          2017      Movie      NaN
#
#   netflix_cast country date_added
# 0          NaN     NaN        NaN
# 1          NaN     NaN        NaN
# 2          NaN     NaN        NaN
# ...

# %%
from config import password
from sqlalchemy import create_engine
conn= f"postgresql://postgres:{password}@localhost:5432/movieflicks_db"
engine= create_engine(conn)

# %%
engine.table_names()
# Out:
# ['netflix', 'netflix_cast', 'movies']

# %%
clean_netflix_df.to_sql(con=engine, name="netflix", if_exists="append", index=False)

# %%
netflix_cast.to_sql(con=engine, name="netflix_cast", if_exists="append", index=False)

# %%
reduced_movies_df.to_sql(con=engine, name="movies", if_exists="append", index=False)
